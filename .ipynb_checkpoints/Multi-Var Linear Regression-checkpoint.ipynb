# %%
import numpy as np
import matplotlib.pyplot as plt


data = np.loadtxt(open("ex1data2.txt"),delimiter = ',')
#print(data)
X = np.array(data[:,0:2])
#X = np.c_[X,data[:,1]]
y = np.array(data[:,2])
y.shape = (len(y),1)
theta = np.zeros((3,1))
#size, bedrooms -> price


#print(X)
print(X)
print(y)
print(theta)
print("X = ", X.shape)
print("Theta = ",theta.shape)
print("y = ",y.shape)
# Out:
# [[2.104e+03 3.000e+00]
#  [1.600e+03 3.000e+00]
#  [2.400e+03 3.000e+00]
#  [1.416e+03 2.000e+00]
#  [3.000e+03 4.000e+00]
#  [1.985e+03 4.000e+00]
#  [1.534e+03 3.000e+00]
#  [1.427e+03 3.000e+00]
#  [1.380e+03 3.000e+00]
#  [1.494e+03 3.000e+00]
#  [1.940e+03 4.000e+00]
#  [2.000e+03 3.000e+00]
#  [1.890e+03 3.000e+00]
#  [4.478e+03 5.000e+00]
#  [1.268e+03 3.000e+00]
#  [2.300e+03 4.000e+00]
#  [1.320e+03 2.000e+00]
#  [1.236e+03 3.000e+00]
#  [2.609e+03 4.000e+00]
#  [3.031e+03 4.000e+00]
#  [1.767e+03 3.000e+00]
#  [1.888e+03 2.000e+00]
#  [1.604e+03 3.000e+00]
#  [1.962e+03 4.000e+00]
#  [3.890e+03 3.000e+00]
#  [1.100e+03 3.000e+00]
#  [1.458e+03 3.000e+00]
#  [2.526e+03 3.000e+00]
#  [2.200e+03 3.000e+00]
#  [2.637e+03 3.000e+00]
#  [1.839e+03 2.000e+00]
#  [1.000e+03 1.000e+00]
#  [2.040e+03 4.000e+00]
#  [3.137e+03 3.000e+00]
#  [1.811e+03 4.000e+00]
#  [1.437e+03 3.000e+00]
#  [1.239e+03 3.000e+00]
#  [2.132e+03 4.000e+00]
#  [4.215e+03 4.000e+00]
#  [2.162e+03 4.000e+00]
#  [1.664e+03 2.000e+00]
#  [2.238e+03 3.000e+00]
#  [2.567e+03 4.000e+00]
#  [1.200e+03 3.000e+00]
#  [8.520e+02 2.000e+00]
#  [1.852e+03 4.000e+00]
#  [1.203e+03 3.000e+00]]
# [[399900.]
#  [329900.]
#  [369000.]
#  [232000.]
#  [539900.]
#  [299900.]
#  [314900.]
#  [198999.]
#  [212000.]
#  [242500.]
#  [239999.]
#  [347000.]
#  [329999.]
#  [699900.]
#  [259900.]
#  [449900.]
#  [299900.]
#  [199900.]
#  [499998.]
#  [599000.]
#  [252900.]
#  [255000.]
#  [242900.]
#  [259900.]
#  [573900.]
#  [249900.]
#  [464500.]
#  [469000.]
#  [475000.]
#  [299900.]
#  [349900.]
#  [169900.]
#  [314900.]
#  [579900.]
#  [285900.]
#  [249900.]
#  [229900.]
#  [345000.]
#  [549000.]
#  [287000.]
#  [368500.]
#  [329900.]
#  [314000.]
#  [299000.]
#  [179900.]
#  [299900.]
#  [239500.]]
# [[0.]
#  [0.]
#  [0.]]
# X =  (47, 2)
# Theta =  (3, 1)
# y =  (47, 1)

# %%
mu = np.zeros((1,np.size(X,1)))
for x in range(0,np.size(X,1)):
    mu[0][x] = np.mean(X[:,x])
print(mu)
X = X - mu
print(X)
# Out:
# [[1.78996298e-13 1.16105707e-13]]
# [[ 1.03319149e+02 -1.70212766e-01]
#  [-4.00680851e+02 -1.70212766e-01]
#  [ 3.99319149e+02 -1.70212766e-01]
#  [-5.84680851e+02 -1.17021277e+00]
#  [ 9.99319149e+02  8.29787234e-01]
#  [-1.56808511e+01  8.29787234e-01]
#  [-4.66680851e+02 -1.70212766e-01]
#  [-5.73680851e+02 -1.70212766e-01]
#  [-6.20680851e+02 -1.70212766e-01]
#  [-5.06680851e+02 -1.70212766e-01]
#  [-6.06808511e+01  8.29787234e-01]
#  [-6.80851064e-01 -1.70212766e-01]
#  [-1.10680851e+02 -1.70212766e-01]
#  [ 2.47731915e+03  1.82978723e+00]
#  [-7.32680851e+02 -1.70212766e-01]
#  [ 2.99319149e+02  8.29787234e-01]
#  [-6.80680851e+02 -1.17021277e+00]
#  [-7.64680851e+02 -1.70212766e-01]
#  [ 6.08319149e+02  8.29787234e-01]
#  [ 1.03031915e+03  8.29787234e-01]
#  [-2.33680851e+02 -1.70212766e-01]
#  [-1.12680851e+02 -1.17021277e+00]
#  [-3.96680851e+02 -1.70212766e-01]
#  [-3.86808511e+01  8.29787234e-01]
#  [ 1.88931915e+03 -1.70212766e-01]
#  [-9.00680851e+02 -1.70212766e-01]
#  [-5.42680851e+02 -1.70212766e-01]
#  [ 5.25319149e+02 -1.70212766e-01]
#  [ 1.99319149e+02 -1.70212766e-01]
#  [ 6.36319149e+02 -1.70212766e-01]
#  [-1.61680851e+02 -1.17021277e+00]
#  [-1.00068085e+03 -2.17021277e+00]
#  [ 3.93191489e+01  8.29787234e-01]
#  [ 1.13631915e+03 -1.70212766e-01]
#  [-1.89680851e+02  8.29787234e-01]
#  [-5.63680851e+02 -1.70212766e-01]
#  [-7.61680851e+02 -1.70212766e-01]
#  [ 1.31319149e+02  8.29787234e-01]
#  [ 2.21431915e+03  8.29787234e-01]
#  [ 1.61319149e+02  8.29787234e-01]
#  [-3.36680851e+02 -1.17021277e+00]
#  [ 2.37319149e+02 -1.70212766e-01]
#  [ 5.66319149e+02  8.29787234e-01]
#  [-8.00680851e+02 -1.70212766e-01]
#  [-1.14868085e+03 -1.17021277e+00]
#  [-1.48680851e+02  8.29787234e-01]
#  [-7.97680851e+02 -1.70212766e-01]]

# %%
def FeatureNormalise(X):
    mu = np.zeros((1,np.size(X,1)))
    sigma = np.zeros((1,np.size(X,1)))
    for x in range(0,np.size(X,1)):
        mu[0][x] = np.mean(X[:,x])
    print(mu)
    X = X - mu
    for x in range(0,np.size(X,1)):
        sigma[0][x] = np.mean(X[:,x])
    print(sigma)
    X[0,:] = 
    
    
    


def computeCost(X,y,theta):
    m = len(y)
    J = 0
    new_arr = (np.dot(X,theta) - y)
    #print(new_arr)
    new_arr = np.square(new_arr)
    sq = np.sum(new_arr)
    J = sq * (1/(2*m))
    return J
    
def GradientDescent(X,y,theta,alpha,iterations):
    m = len(y)
    J_history = np.array([])
    for x in range(iterations):
        pred = np.dot(X,theta)
        delta = (1/m)*np.dot( (pred-y).transpose(),X).transpose()
        #print(delta.shape)
        theta = theta - alpha*delta
        newCost = computeCost(X,y,theta)
        J_history = np.append(J_history,newCost)
    print(theta)    
    return theta,J_history


A = np.ones(len(y))
X = np.c_[A,X]    
alpha = 0.01
iterations = 400
cost = computeCost(X,y,theta)
print("Initial cost will zero thetas : ",cost)

theta,J_history = GradientDescent(X,y,theta,alpha,iterations)
print(theta)
J_history.shape = (iterations,1)
print(J_history)
iterator = [x for x in range(1,iterations+1)]
plt.plot(iterator,J_history)
plt.xlabel("No of iterations")
plt.ylabel("Value of cost fn")
# Out:
# Initial cost will zero thetas :  65591548106.45744
# [[nan]
#  [nan]
#  [nan]]
# [[nan]
#  [nan]
#  [nan]]
# [[1.34926868e+020]
#  [2.88086682e+029]
#  [6.15103114e+038]
#  [1.31332638e+048]
#  [2.80412528e+057]
#  [5.98717780e+066]
#  [1.27834153e+076]
#  [2.72942800e+085]
#  [5.82768926e+094]
#  [1.24428862e+104]
#  [2.65672054e+113]
#  [5.67244922e+122]
#  [1.21114282e+132]
#  [2.58594988e+141]
#  [5.52134452e+150]
#  [1.17887997e+160]
#  [2.51706444e+169]
#  [5.37426500e+178]
#  [1.14747656e+188]
#  [2.45001399e+197]
#  [5.23110344e+206]
#  [1.11690967e+216]
#  [2.38474966e+225]
#  [5.09175547e+234]
#  [1.08715704e+244]
#  [2.32122386e+253]
#  [4.95611949e+262]
#  [1.05819697e+272]
#  [2.25939028e+281]
#  [4.82409664e+290]
#  [1.03000834e+300]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            inf]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]]
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in square
#
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in subtract
# Text(0, 0.5, 'Value of cost fn')
